# %% [markdown]
# <a href="https://colab.research.google.com/github/shaunck96/AI-Generated-News/blob/main/News_Article_Extractor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install newspaper3k
# !pip install scrapetube==2.5.1
# !pip install pytube==15.0.0
# !pip install huggingsound==0.1.6
# !pip install transformers==4.35.2
# !pip install requests==2.31.0
# !pip install tqdm==4.66.1
# !pip install openai==0.28
# !pip install faster-whisper==0.9.0
# !pip install eyed3==0.9.7
# !pip install tiktoken==0.5.1
# !pip install langchain==0.0.340
# !pip install youtube-comment-downloader==0.1.70
# !pip install guardrails-ai
# !pip install -q streamlit
# !pip install newsapi-python
# Out:
# Requirement already satisfied: newspaper3k in /usr/local/lib/python3.10/dist-packages (0.2.8)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (4.11.2)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (9.4.0)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (6.0.1)
# Requirement already satisfied: cssselect>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (1.2.0)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (4.9.3)
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (3.8.1)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (2.31.0)
# Requirement already satisfied: feedparser>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (6.0.10)
# Requirement already satisfied: tldextract>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (5.1.1)
# Requirement already satisfied: feedfinder2>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: jieba3k>=0.35.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (2.8.2)
# Requirement already satisfied: tinysegmenter==0.3 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.10/dist-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (4.66.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->newspaper3k) (2023.7.22)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.10/dist-packages (from tldextract>=2.0.1->newspaper3k) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.10/dist-packages (from tldextract>=2.0.1->newspaper3k) (3.13.1)
# Collecting scrapetube==2.5.1
#   Downloading scrapetube-2.5.1-py3-none-any.whl (5.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from scrapetube==2.5.1) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from scrapetube==2.5.1) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->scrapetube==2.5.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->scrapetube==2.5.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->scrapetube==2.5.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->scrapetube==2.5.1) (2023.7.22)
# Installing collected packages: scrapetube
# Successfully installed scrapetube-2.5.1
# Collecting pytube==15.0.0
#   Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0
# Collecting huggingsound==0.1.6
#   Downloading huggingsound-0.1.6-py3-none-any.whl (28 kB)
# Collecting datasets<3.0.0,>=2.6.1 (from huggingsound==0.1.6)
#   Downloading datasets-2.15.0-py3-none-any.whl (521 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 11.2 MB/s eta 0:00:00
# Collecting jiwer<3.0.0,>=2.5.1 (from huggingsound==0.1.6)
#   Downloading jiwer-2.6.0-py3-none-any.whl (20 kB)
# Collecting librosa<0.10.0,>=0.9.2 (from huggingsound==0.1.6)
#   Downloading librosa-0.9.2-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 kB 25.7 MB/s eta 0:00:00
# Collecting torch!=1.12.0,<1.13.0,>=1.7 (from huggingsound==0.1.6)
#   Downloading torch-1.12.1-cp310-cp310-manylinux1_x86_64.whl (776.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.23.1 in /usr/local/lib/python3.10/dist-packages (from huggingsound==0.1.6) (4.35.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (9.0.0)
# Collecting pyarrow-hotfix (from datasets<3.0.0,>=2.6.1->huggingsound==0.1.6)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets<3.0.0,>=2.6.1->huggingsound==0.1.6)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (3.4.1)
# Collecting multiprocess (from datasets<3.0.0,>=2.6.1->huggingsound==0.1.6)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (3.8.6)
# Requirement already satisfied: huggingface-hub>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (0.19.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (6.0.1)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer<3.0.0,>=2.5.1->huggingsound==0.1.6) (8.1.7)
# Collecting rapidfuzz==2.13.7 (from jiwer<3.0.0,>=2.5.1->huggingsound==0.1.6)
#   Downloading rapidfuzz-2.13.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 91.4 MB/s eta 0:00:00
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa<0.10.0,>=0.9.2->huggingsound==0.1.6) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa<0.10.0,>=0.9.2->huggingsound==0.1.6) (1.11.3)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from librosa<0.10.0,>=0.9.2->huggingsound==0.1.6) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa<0.10.0,>=0.9.2->huggingsound==0.1.6) (1.3.2)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.10/dist-packages (from librosa<0.10.0,>=0.9.2->huggingsound==0.1.6) (4.4.2)
# Collecting resampy>=0.2.2 (from librosa<0.10.0,>=0.9.2->huggingsound==0.1.6)
#   Downloading resampy-0.4.2-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 85.4 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.45.1 in /usr/local/lib/python3.10/dist-packages (from librosa<0.10.0,>=0.9.2->huggingsound==0.1.6) (0.58.1)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from librosa<0.10.0,>=0.9.2->huggingsound==0.1.6) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa<0.10.0,>=0.9.2->huggingsound==0.1.6) (1.8.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,<1.13.0,>=1.7->huggingsound==0.1.6) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.23.1->huggingsound==0.1.6) (3.13.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.23.1->huggingsound==0.1.6) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.23.1->huggingsound==0.1.6) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.23.1->huggingsound==0.1.6) (0.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (1.3.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.45.1->librosa<0.10.0,>=0.9.2->huggingsound==0.1.6) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa<0.10.0,>=0.9.2->huggingsound==0.1.6) (4.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->librosa<0.10.0,>=0.9.2->huggingsound==0.1.6) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.10.2->librosa<0.10.0,>=0.9.2->huggingsound==0.1.6) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (2023.3.post1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa<0.10.0,>=0.9.2->huggingsound==0.1.6) (2.21)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets<3.0.0,>=2.6.1->huggingsound==0.1.6) (1.16.0)
# Installing collected packages: torch, rapidfuzz, pyarrow-hotfix, dill, resampy, multiprocess, jiwer, librosa, datasets, huggingsound
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0+cu118
#     Uninstalling torch-2.1.0+cu118:
#       Successfully uninstalled torch-2.1.0+cu118
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.1
#     Uninstalling librosa-0.10.1:
#       Successfully uninstalled librosa-0.10.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.1.0+cu118 requires torch==2.1.0, but you have torch 1.12.1 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 1.12.1 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 1.12.1 which is incompatible.
# torchvision 0.16.0+cu118 requires torch==2.1.0, but you have torch 1.12.1 which is incompatible.
# Successfully installed datasets-2.15.0 dill-0.3.7 huggingsound-0.1.6 jiwer-2.6.0 librosa-0.9.2 multiprocess-0.70.15 pyarrow-hotfix-0.6 rapidfuzz-2.13.7 resampy-0.4.2 torch-1.12.1
# Requirement already satisfied: transformers==4.35.2 in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.35.2) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.35.2) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.35.2) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.35.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.35.2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.35.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.35.2) (2023.7.22)
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.31.0) (2023.7.22)
# Requirement already satisfied: tqdm==4.66.1 in /usr/local/lib/python3.10/dist-packages (4.66.1)
# Collecting openai==0.28
#   Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (3.8.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.3.1)
# Installing collected packages: openai
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# Successfully installed openai-0.28.0
# Collecting faster-whisper==0.9.0
#   Downloading faster_whisper-0.9.0-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 17.2 MB/s eta 0:00:00
# Collecting av==10.* (from faster-whisper==0.9.0)
#   Downloading av-10.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.0/31.0 MB 58.3 MB/s eta 0:00:00
# Collecting ctranslate2<4,>=3.17 (from faster-whisper==0.9.0)
#   Downloading ctranslate2-3.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.8/36.8 MB 16.8 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.13 in /usr/local/lib/python3.10/dist-packages (from faster-whisper==0.9.0) (0.19.4)
# Collecting tokenizers<0.15,>=0.13 (from faster-whisper==0.9.0)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 116.4 MB/s eta 0:00:00
# Collecting onnxruntime<2,>=1.14 (from faster-whisper==0.9.0)
#   Downloading onnxruntime-1.16.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 122.4 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from ctranslate2<4,>=3.17->faster-whisper==0.9.0) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ctranslate2<4,>=3.17->faster-whisper==0.9.0) (1.23.5)
# Requirement already satisfied: pyyaml<7,>=5.3 in /usr/local/lib/python3.10/dist-packages (from ctranslate2<4,>=3.17->faster-whisper==0.9.0) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper==0.9.0) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper==0.9.0) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper==0.9.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper==0.9.0) (4.66.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper==0.9.0) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper==0.9.0) (23.2)
# Collecting coloredlogs (from onnxruntime<2,>=1.14->faster-whisper==0.9.0)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster-whisper==0.9.0) (23.5.26)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster-whisper==0.9.0) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster-whisper==0.9.0) (1.12)
# Collecting huggingface-hub>=0.13 (from faster-whisper==0.9.0)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 33.2 MB/s eta 0:00:00
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<2,>=1.14->faster-whisper==0.9.0)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper==0.9.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper==0.9.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper==0.9.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper==0.9.0) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime<2,>=1.14->faster-whisper==0.9.0) (1.3.0)
# Installing collected packages: av, humanfriendly, ctranslate2, huggingface-hub, coloredlogs, tokenizers, onnxruntime, faster-whisper
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.19.4
#     Uninstalling huggingface-hub-0.19.4:
#       Successfully uninstalled huggingface-hub-0.19.4
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.0
#     Uninstalling tokenizers-0.15.0:
#       Successfully uninstalled tokenizers-0.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 2.15.0 requires huggingface-hub>=0.18.0, but you have huggingface-hub 0.17.3 which is incompatible.
# Successfully installed av-10.0.0 coloredlogs-15.0.1 ctranslate2-3.22.0 faster-whisper-0.9.0 huggingface-hub-0.17.3 humanfriendly-10.0 onnxruntime-1.16.3 tokenizers-0.14.1
# Collecting eyed3==0.9.7
#   Downloading eyed3-0.9.7-py3-none-any.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.1/246.1 kB 5.6 MB/s eta 0:00:00
# Collecting coverage[toml]<6.0.0,>=5.3.1 (from eyed3==0.9.7)
#   Downloading coverage-5.5-cp310-cp310-manylinux1_x86_64.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.0/239.0 kB 31.1 MB/s eta 0:00:00
# Collecting deprecation<3.0.0,>=2.1.0 (from eyed3==0.9.7)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting filetype<2.0.0,>=1.0.7 (from eyed3==0.9.7)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from coverage[toml]<6.0.0,>=5.3.1->eyed3==0.9.7) (0.10.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation<3.0.0,>=2.1.0->eyed3==0.9.7) (23.2)
# Installing collected packages: filetype, deprecation, coverage, eyed3
# Successfully installed coverage-5.5 deprecation-2.1.0 eyed3-0.9.7 filetype-1.2.0
# Collecting tiktoken==0.5.1
#   Downloading tiktoken-0.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 24.5 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken==0.5.1) (2023.6.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken==0.5.1) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.5.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.5.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.5.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken==0.5.1) (2023.7.22)
# Installing collected packages: tiktoken
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# Successfully installed tiktoken-0.5.1
# Collecting langchain==0.0.340
#   Downloading langchain-0.0.340-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 24.9 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.340) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.340) (2.0.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.340) (3.8.6)
# Requirement already satisfied: anyio<4.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.340) (3.7.1)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.340) (4.0.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain==0.0.340)
#   Downloading dataclasses_json-0.6.3-py3-none-any.whl (28 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain==0.0.340)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langsmith<0.1.0,>=0.0.63 (from langchain==0.0.340)
#   Downloading langsmith-0.0.67-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.340) (1.23.5)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.340) (1.10.13)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.340) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.0.340) (8.2.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.340) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.340) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.340) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.340) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.340) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.340) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain==0.0.340) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain==0.0.340) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain==0.0.340) (1.1.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain==0.0.340)
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.0 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain==0.0.340)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain==0.0.340)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain==0.0.340) (4.5.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain==0.0.340) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain==0.0.340) (2023.7.22)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.0.340) (3.0.1)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.7,>=0.5.7->langchain==0.0.340) (23.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.0.340)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: mypy-extensions, marshmallow, jsonpointer, typing-inspect, langsmith, jsonpatch, dataclasses-json, langchain
# Successfully installed dataclasses-json-0.6.3 jsonpatch-1.33 jsonpointer-2.4 langchain-0.0.340 langsmith-0.0.67 marshmallow-3.20.1 mypy-extensions-1.0.0 typing-inspect-0.9.0
# Collecting youtube-comment-downloader==0.1.70
#   Downloading youtube_comment_downloader-0.1.70-py3-none-any.whl (7.9 kB)
# Collecting dateparser (from youtube-comment-downloader==0.1.70)
#   Downloading dateparser-1.2.0-py2.py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from youtube-comment-downloader==0.1.70) (2.31.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from dateparser->youtube-comment-downloader==0.1.70) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from dateparser->youtube-comment-downloader==0.1.70) (2023.3.post1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.10/dist-packages (from dateparser->youtube-comment-downloader==0.1.70) (2023.6.3)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser->youtube-comment-downloader==0.1.70) (5.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-comment-downloader==0.1.70) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-comment-downloader==0.1.70) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-comment-downloader==0.1.70) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-comment-downloader==0.1.70) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->dateparser->youtube-comment-downloader==0.1.70) (1.16.0)
# Installing collected packages: dateparser, youtube-comment-downloader
# Successfully installed dateparser-1.2.0 youtube-comment-downloader-0.1.70
# Collecting guardrails-ai
#   Downloading guardrails_ai-0.2.9-py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.5/100.5 kB 3.0 MB/s eta 0:00:00
# Collecting eliot<2.0.0,>=1.15.0 (from guardrails-ai)
#   Downloading eliot-1.15.0-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.1/113.1 kB 6.1 MB/s eta 0:00:00
# Collecting eliot-tree<22.0.0,>=21.0.0 (from guardrails-ai)
#   Downloading eliot_tree-21.0.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 6.1 MB/s eta 0:00:00
# Collecting griffe<0.37.0,>=0.36.9 (from guardrails-ai)
#   Downloading griffe-0.36.9-py3-none-any.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: lxml<5.0.0,>=4.9.3 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (4.9.3)
# Requirement already satisfied: openai<2 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (0.28.0)
# Requirement already satisfied: pydantic<2.5,>=1.10.9 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (1.10.13)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (2.8.2)
# Collecting regex<2024.0.0,>=2023.10.3 (from guardrails-ai)
#   Downloading regex-2023.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (773 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 773.9/773.9 kB 28.2 MB/s eta 0:00:00
# Requirement already satisfied: rich<14.0.0,>=13.6.0 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (13.7.0)
# Collecting rstr<4.0.0,>=3.2.2 (from guardrails-ai)
#   Downloading rstr-3.2.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: tenacity>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (8.2.3)
# Requirement already satisfied: typer<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from guardrails-ai) (0.9.0)
# Collecting typing-extensions<5.0.0,>=4.8.0 (from guardrails-ai)
#   Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from eliot<2.0.0,>=1.15.0->guardrails-ai) (1.16.0)
# Collecting zope.interface (from eliot<2.0.0,>=1.15.0->guardrails-ai)
#   Downloading zope.interface-6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.1/247.1 kB 31.8 MB/s eta 0:00:00
# Collecting pyrsistent>=0.11.8 (from eliot<2.0.0,>=1.15.0->guardrails-ai)
#   Downloading pyrsistent-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 18.9 MB/s eta 0:00:00
# Collecting boltons>=19.0.1 (from eliot<2.0.0,>=1.15.0->guardrails-ai)
#   Downloading boltons-23.1.1-py2.py3-none-any.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.3/195.3 kB 26.7 MB/s eta 0:00:00
# Collecting orjson (from eliot<2.0.0,>=1.15.0->guardrails-ai)
#   Downloading orjson-3.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 22.1 MB/s eta 0:00:00
# Collecting jmespath>=0.7.1 (from eliot-tree<22.0.0,>=21.0.0->guardrails-ai)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting iso8601>=0.1.10 (from eliot-tree<22.0.0,>=21.0.0->guardrails-ai)
#   Downloading iso8601-2.1.0-py3-none-any.whl (7.5 kB)
# Collecting colored>=1.4.2 (from eliot-tree<22.0.0,>=21.0.0->guardrails-ai)
#   Downloading colored-2.2.3-py3-none-any.whl (16 kB)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from eliot-tree<22.0.0,>=21.0.0->guardrails-ai) (0.12.0)
# Collecting colorama>=0.4 (from griffe<0.37.0,>=0.36.9->guardrails-ai)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai<2->guardrails-ai) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai<2->guardrails-ai) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai<2->guardrails-ai) (3.8.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.6.0->guardrails-ai) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.6.0->guardrails-ai) (2.16.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.9.0->guardrails-ai) (8.1.7)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.6.0->guardrails-ai) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai<2->guardrails-ai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai<2->guardrails-ai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai<2->guardrails-ai) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai<2->guardrails-ai) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai<2->guardrails-ai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai<2->guardrails-ai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai<2->guardrails-ai) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai<2->guardrails-ai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai<2->guardrails-ai) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai<2->guardrails-ai) (1.3.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from zope.interface->eliot<2.0.0,>=1.15.0->guardrails-ai) (67.7.2)
# Installing collected packages: boltons, zope.interface, typing-extensions, rstr, regex, pyrsistent, orjson, jmespath, iso8601, colored, colorama, griffe, eliot, eliot-tree, guardrails-ai
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: regex
#     Found existing installation: regex 2023.6.3
#     Uninstalling regex-2023.6.3:
#       Successfully uninstalled regex-2023.6.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.8.0 which is incompatible.
# torchaudio 2.1.0+cu118 requires torch==2.1.0, but you have torch 1.12.1 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 1.12.1 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 1.12.1 which is incompatible.
# torchvision 0.16.0+cu118 requires torch==2.1.0, but you have torch 1.12.1 which is incompatible.
# Successfully installed boltons-23.1.1 colorama-0.4.6 colored-2.2.3 eliot-1.15.0 eliot-tree-21.0.0 griffe-0.36.9 guardrails-ai-0.2.9 iso8601-2.1.0 jmespath-1.0.1 orjson-3.9.10 pyrsistent-0.20.0 regex-2023.10.3 rstr-3.2.2 typing-extensions-4.8.0 zope.interface-6.1
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 60.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 21.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 99.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.1 MB/s eta 0:00:00

# %%
import pandas as pd
import scrapetube
from pytube import YouTube
import os
import librosa
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
import os
import openai
import regex as re
import json
import requests
from tqdm import tqdm
from googleapiclient.discovery import build
import regex as re
from transformers import pipeline
from faster_whisper import WhisperModel
from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
from faster_whisper import WhisperModel
import tiktoken
import pandas as pd
import re
from urllib import parse
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import ast
from langchain.output_parsers import StructuredOutputParser, ResponseSchema
from langchain.prompts import PromptTemplate, ChatPromptTemplate, HumanMessagePromptTemplate
from langchain.chat_models import ChatOpenAI
from itertools import islice
from youtube_comment_downloader import *
from pydantic import BaseModel, Field
from langchain.output_parsers import PydanticOutputParser
from pydantic import BaseModel, Field
from langchain.output_parsers import PydanticOutputParser
from itertools import islice
from youtube_comment_downloader import *
from pytube import YouTube
import cv2
import base64
import requests
from PIL import Image
from pathlib import Path
from moviepy import editor
import os
import torch
import imageio
import os
import requests
import googleapiclient.discovery
from langchain.llms import OpenAI
from langchain.output_parsers import PydanticOutputParser
from langchain.prompts import PromptTemplate
from langchain.pydantic_v1 import BaseModel, Field, validator
from langchain.llms import OpenAI
import requests
import requests
from langchain.chains.summarize import load_summarize_chain
from langchain.docstore.document import Document
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
url = 'http://fox13now.com/2013/12/30/new-year-new-laws-obamacare-pot-guns-and-drones/'
article = Article(url)
article.download()
print(article.parse())
print(article.authors)
print(article.publish_date)
print(article.text)
print(article.top_image)
print(article.movies)
article.nlp()
print(article.keywords)

# %%
cnn_paper = newspaper.build('http://bbc.com')
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.bbc.co.uk/feed
# CRITICAL:newspaper.network:[REQUEST FAILED] 404 Client Error: Not Found for url: https://www.bbc.co.uk/rss
# CRITICAL:newspaper.network:[REQUEST FAILED] Exceeded 30 redirects.

# %%
for article in cnn_paper.articles:
  print(article.url)
# Out:
# http://bbc.com/news/world-us-canada-67587867
# http://bbc.com/news/world-africa-67565784
# http://bbc.com/news/world-africa-67586565
# http://bbc.com/news/world-europe-67587331
# http://bbc.com/news/world-latin-america-19649648
# http://bbc.com/news/business-67583574
# http://bbc.com/news/uk-scotland-scotland-business-67587508
# https://www.bbc.co.uk/news/uk-67588099
# https://www.bbc.co.uk/news/live/health-67572394
# https://www.bbc.co.uk/news/health
# https://www.bbc.co.uk/news/business-67587236
# https://www.bbc.co.uk/news/world-us-canada-67587867
# https://www.bbc.co.uk/news/uk-england-birmingham-67588149
# https://www.bbc.co.uk/news/uk-scotland-67589431
# https://www.bbc.co.uk/programmes/articles/MQhbhvdy9PkqMC33d1R9My/vote-for-your-ultimate-madonna-song
# RT
# RTE
# RTL Nieuws
# SABQ
# Spiegel Online
# Svenska Dagbladet
# T3n
# TalkSport
# TechCrunch
# TechCrunch (CN)
# TechRadar
# The American Conservative
# The Globe And Mail
# The Hill
# The Hindu
# The Huffington Post
# The Irish Times
# The Jerusalem Post
# The Lad Bible
# The Next Web
# The Sport Bible
# The Times of India
# The Verge
# The Wall Street Journal
# The Washington Post
# The Washington Times
# Time
# USA Today
# Vice News
# Wired
# Wired.de
# Wirtschafts Woche
# Xinhua Net
# Ynet

# %%
top_headlines = newsapi.get_top_headlines(
    q='PPL Corporation',
    language='en',
)
top_headlines
# Out:
# {'status': 'ok', 'totalResults': 0, 'articles': []}

# %%
for article in top_headlines['articles']:
    print('Title : ',article['title'])
    print('Description : ',article['description'],'\n\n')

# %%
newspaper_df = pd.DataFrame(columns=['Source','Title','Description'])
all_articles = newsapi.get_everything(
    q='PPL Corporation',
    language='en',
    from_param='2023-11-01',
    sort_by='relevancy'
)
for article in all_articles['articles']:
    print('Source : ',article['source']['name'])
    print('Title : ',article['title'])
    print('Description : ',article['description'],'\n\n')
    newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)

newspaper_df.head(20)
# Out:
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
# Source :  Marketscreener.com
# Title :  PPL to Pay Quarterly Stock Dividend January 2, 2024
# Description :  (marketscreener.com)
#
# ALLENTOWN, Pa., Nov. 17, 2023 /PRNewswire/ -- PPL Corporation declared a quarterly common stock dividend on Friday, November 17, of $0.24 per share, payable January 2, 2024, to shareowners of record as of December 8, 2023.
#
# PPL Corporat…
#
#
# Source :  Marketscreener.com
# Title :  PPL Corporation reports third-quarter 2023 earnings
# Description :  (marketscreener.com) net
# 16
# 10
# 51
# 36
# Interest Expense
# 165
# 136
# 494
# 361
# Income Before Income Taxes
# 288
# 215
# 797
# 713
# Income Taxes
# 58
# 41
# 170
# 147
# Net Income
# $                230
# $               ...https://www.marketscreener.com/quote/stock/PPL-CORPORATION-14091/new…
#
#
# Source :  Marketscreener.com
# Title :  PPL to attend 58th EEI Financial Conference
# Description :  (marketscreener.com)
#
# ALLENTOWN, Pa., Nov. 10, 2023 /PRNewswire/ -- PPL Corporation senior leadership will attend the 58th Edison Electric Institute Financial Conference this Sunday, Nov. 12, to Tuesday, Nov. 14, in Phoenix.
#
# During the conference, company l…
#
#
# Source :  Marketscreener.com
# Title :  PPL's Kentucky subsidiaries receive constructive regulatory order approving substantial portion of generation investment plan
# Description :  (marketscreener.com)
#
# Approvals include retirement of 600 MW of aging coal generation and additions of one approximately 640-MW combined cycle natural gas plant and more than 1,000 MW of solar and energy storage by 2027.PPL reaffirms capital outlook; continu…
#
#
# Source :  InvestorsObserver
# Title :  Pembina Pipeline Corporation Announces Conversion Results for Series 1 Preferred Shares
# Description :  Pembina Pipeline Corporation ("Pembina") (TSX: PPL; NYSE: PBA) announced today that none of Pembina's Cumulative Redeemable Rate Reset Class A Preferred Shares, Series 1 ("Series 1 Shares") (TSX: PPL.PR.A) will be converted into Cumulative Redeemable F...
#
#
# Source :  ETF Daily News
# Title :  PPL (NYSE:PPL) Issues FY23 Earnings Guidance
# Description :  PPL (NYSE:PPL – Get Free Report) updated its FY23 earnings guidance on Thursday. The company provided EPS guidance of $1.55-1.60 for the period, compared to the consensus EPS estimate of $1.58. Analyst Ratings Changes PPL has been the subject of a number of r…
#
#
# Source :  ETF Daily News
# Title :  PPL Co. (NYSE:PPL) Receives Consensus Rating of “Hold” from Brokerages
# Description :  Shares of PPL Co. (NYSE:PPL – Get Free Report) have earned a consensus recommendation of “Hold” from the six research firms that are currently covering the firm, MarketBeat reports. Four investment analysts have rated the stock with a hold rating and two have…
#
#
# Source :  ETF Daily News
# Title :  Terna (OTCMKTS:TERRF) vs. PPL (NYSE:PPL) Head to Head Analysis
# Description :  Terna (OTCMKTS:TERRF – Get Free Report) and PPL (NYSE:PPL – Get Free Report) are both utilities companies, but which is the superior investment? We will contrast the two businesses based on the strength of their institutional ownership, dividends, analyst rec…
#
#
# Source :  ETF Daily News
# Title :  PPL (NYSE:PPL) Price Target Increased to $30.00 by Analysts at Morgan Stanley
# Description :  PPL (NYSE:PPL – Get Free Report) had its price target boosted by analysts at Morgan Stanley from $28.00 to $30.00 in a note issued to investors on Tuesday, Benzinga reports. The brokerage currently has an “overweight” rating on the utilities provider’s stock.…
#
#
# Source :  ETF Daily News
# Title :  Hotchkis & Wiley Capital Management LLC Cuts Position in PPL Co. (NYSE:PPL)
# Description :  Hotchkis & Wiley Capital Management LLC cut its stake in PPL Co. (NYSE:PPL – Free Report) by 0.9% in the 2nd quarter, according to its most recent disclosure with the SEC. The institutional investor owned 15,160,360 shares of the utilities provider’s stock af…
#
#
# Source :  ETF Daily News
# Title :  Guggenheim Capital LLC Has $3.60 Million Stock Holdings in PPL Co. (NYSE:PPL)
# Description :  Guggenheim Capital LLC reduced its stake in PPL Co. (NYSE:PPL – Free Report) by 36.3% during the 2nd quarter, Holdings Channel.com reports. The firm owned 135,881 shares of the utilities provider’s stock after selling 77,395 shares during the period. Guggenhe…
#
#
# Source :  ETF Daily News
# Title :  Inceptionr LLC Makes New $1.13 Million Investment in PPL Co. (NYSE:PPL)
# Description :  Inceptionr LLC bought a new position in PPL Co. (NYSE:PPL – Free Report) in the second quarter, according to its most recent 13F filing with the Securities & Exchange Commission. The institutional investor bought 42,541 shares of the utilities provider’s stoc…
#
#
# Source :  ETF Daily News
# Title :  42,541 Shares in PPL Co. (NYSE:PPL) Purchased by Inceptionr LLC
# Description :  Inceptionr LLC acquired a new position in PPL Co. (NYSE:PPL – Free Report) in the second quarter, according to its most recent disclosure with the Securities & Exchange Commission. The institutional investor acquired 42,541 shares of the utilities provider’s …
#
#
# Source :  ETF Daily News
# Title :  Allegheny Financial Group LTD Cuts Stock Holdings in PPL Co. (NYSE:PPL)
# Description :  Allegheny Financial Group LTD lessened its holdings in PPL Co. (NYSE:PPL – Free Report) by 3.9% in the 2nd quarter, according to its most recent filing with the SEC. The firm owned 10,275 shares of the utilities provider’s stock after selling 413 shares durin…
#
#
# Source :  ETF Daily News
# Title :  Public Employees Retirement Association of Colorado Lowers Stock Holdings in PPL Co. (NYSE:PPL)
# Title :  Pembina Pipeline Corporation Provides Notice of Series 1 Preferred Share Conversion Right and Announces Reset Dividend Rates
# Description :  (marketscreener.com)
# Pembina Pipeline Corporation announced today that it does not intend to exercise its right to redeem the currently outstanding Cumulative Redeemable Rate Reset Class A Preferred Shares, Series 1 on December 1, 2023.
#
# This press release f…
#
#
# Source :  ETF Daily News
# Title :  Pembina Pipeline (TSE:PPL) Price Target Lowered to C$49.00 at JPMorgan Chase & Co.
# Description :  Pembina Pipeline (TSE:PPL – Free Report) (NYSE:PBA) had its price target decreased by JPMorgan Chase & Co. from C$50.00 to C$49.00 in a research note issued to investors on Monday, BayStreet.CA reports. JPMorgan Chase & Co. currently has a neutral rating on t…
#
#
# Source :  ETF Daily News
# Title :  Pembina Pipeline Co. Announces Quarterly Dividend of $0.67 (TSE:PPL)
# Description :  Pembina Pipeline Co. (TSE:PPL – Get Free Report) (NYSE:PBA) announced a quarterly dividend on Thursday, November 2nd, Zacks reports. Shareholders of record on Friday, December 15th will be paid a dividend of 0.668 per share on Friday, December 29th. This repr…
#
#
# Source :  ETF Daily News
# Title :  Pembina Pipeline (TSE:PPL) Given New C$49.00 Price Target at Scotiabank
# Description :  Pembina Pipeline (TSE:PPL – Free Report) (NYSE:PBA) had its price target hoisted by Scotiabank from C$48.00 to C$49.00 in a research report released on Friday, BayStreet.CA reports. Scotiabank currently has an outperform rating on the stock. Other equities re…
#
#
# Source :  Marketscreener.com
# Title :
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#
# WARNING:py.warnings:<ipython-input-184-1eee329d18c7>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   newspaper_df = newspaper_df.append({'Source':article['source']['name'],'Title':article['title'],'Description':article['description']},ignore_index=True)
#  Pembina Pipeline Corporation Reports Record Results for the Third Quarter 2023, Raises 2023 Guidance and Declares Quarterly Common Share Dividend
# Description :  (marketscreener.com)
# All financial figures are in Canadian dollars unless otherwise noted. This news release refers to certain financial measures and ratios that are not specified, defined or determined in accordance with Generally Accepted Accounting Princi…
#
#
# Source :  Harvard School of Engineering and Applied Sciences
# Title :  2023 CPA-Zicklin Index Shows Strong Increase in Number of Trendsetter, Top-Scoring Companies
# Description :  With the 2024 election season ramping up, more leading U.S. corporations than ever before are receiving the highest scores for political spending disclosure and accountability, according to the annual benchmarking study recently released by the Center for Pol…
#
#
# Source :  Kernel.org
# Title :  Merge tag 'media/v6.7-1' of git://git.kernel.org/pub/scm/linux/kernel/git/mchehab/linux-media
# Description :  None
#
#
# Source :  Lesswrong.com
# Title :  How much to update on recent AI governance moves?
# Description :  Published on November 16, 2023 11:46 PM GMTNate and I (habryka) discuss the recent increase in public and political attention on AGI ruin. We try and figure out where, if anywhere, we feel extra hope as a result.I think it's plausible that this is enough of a…
#
#
# Source :  Lesswrong.com
# Title :  AI #36: In the Background
# Description :  Published on November 2, 2023 6:00 PM GMTWow, what a week. We had the Executive Order, which I read here so you don’t have to and then I have a tabulation of the reactions of others.
#
#
#
# Simultaneously there was the UK AI Summit.
#
#
#
# There was also robust relat…
#                 Source                                              Title  \
# 0   Marketscreener.com  PPL to Pay Quarterly Stock Dividend January 2,...
# 1   Marketscreener.com  PPL Corporation reports third-quarter 2023 ear...
# 2   Marketscreener.com        PPL to attend 58th EEI Financial Conference
# 3   Marketscreener.com  PPL's Kentucky subsidiaries receive constructi...
# 4    InvestorsObserver  Pembina Pipeline Corporation Announces Convers...
# 5       ETF Daily News       PPL (NYSE:PPL) Issues FY23 Earnings Guidance
# 6       ETF Daily News  PPL Co. (NYSE:PPL) Receives Consensus Rating o...
# 7       ETF Daily News  Terna (OTCMKTS:TERRF) vs. PPL (NYSE:PPL) Head ...
# 8       ETF Daily News  PPL (NYSE:PPL) Price Target Increased to $30.0...
# 9       ETF Daily News  Hotchkis & Wiley Capital Management LLC Cuts P...
# 10      ETF Daily News  Guggenheim Capital LLC Has $3.60 Million Stock...
# 11      ETF Daily News  Inceptionr LLC Makes New $1.13 Million Investm...
# 12      ETF Daily News  42,541 Shares in PPL Co. (NYSE:PPL) Purchased ...
# 13      ETF Daily News  Allegheny Financial Group LTD Cuts Stock Holdi...
# 14      ETF Daily News  Public Employees Retirement Association of Col...
# 15      ETF Daily News  Sound View Wealth Advisors Group LLC Sells 2,1...
# 16      ETF Daily News  Lido Advisors LLC Acquires 8,564 Shares of PPL...
# 17      ETF Daily News  BTG Pactual Global Asset Management Ltd Has $9...
# 18      ETF Daily News  Roffman Miller Associates Inc. PA Cuts Positio...
# 19      ETF Daily News  PPL Co. (NYSE:PPL) Shares Acquired by Magellan...
#
#                                           Description
# 0   (marketscreener.com) \n\nALLENTOWN, Pa., Nov. ...
# 1   (marketscreener.com) net\n16\n10\n51\n36\nInte...
# 2   (marketscreener.com) \n\nALLENTOWN, Pa., Nov. ...
# 3   (marketscreener.com) \n\nApprovals include ret...
# 4   Pembina Pipeline Corporation ("Pembina") (TSX:...
# 5   PPL (NYSE:PPL – Get Free Report) updated its F...
# 6   Shares of PPL Co. (NYSE:PPL – Get Free Report)...
# 7   Terna (OTCMKTS:TERRF – Get Free Report) and PP...
# 8   PPL (NYSE:PPL – Get Free Report) had its price...
# 9   Hotchkis & Wiley Capital Management LLC cut it...
# 10  Guggenheim Capital LLC reduced its stake in PP...
# 11  Inceptionr LLC bought a new position in PPL Co...
# 12  Inceptionr LLC acquired a new position in PPL ...
# 13  Allegheny Financial Group LTD lessened its hol...
# 14  Public Employees Retirement Association of Col...
# 15  Sound View Wealth Advisors Group LLC cut its h...
# 16  Lido Advisors LLC increased its holdings in PP...
# 17  BTG Pactual Global Asset Management Ltd increa...
# 18  Roffman Miller Associates Inc. PA reduced its ...
# 19  Magellan Asset Management Ltd increased its po...

# %%
input_to_llm_two = ""

for index in newspaper_df.index:
  input_to_llm_two+="ARTICLE"+str(index)+"   "
  input_to_llm_two+="ARTICLE SOURCE: "+newspaper_df.at[index,'Source']+"   "
  input_to_llm_two+="ARTICLE TITLE: "+newspaper_df.at[index,'Title']+"   "
  input_to_llm_two+="ARTICLE DESCRIPTION: "+str(newspaper_df.at[index,'Description'])+"   "
  input_to_llm_two+="\n\n"

input_to_llm_two
# Out:
# 'ARTICLE0   ARTICLE SOURCE: Marketscreener.com   ARTICLE TITLE: PPL to Pay Quarterly Stock Dividend January 2, 2024   ARTICLE DESCRIPTION: (marketscreener.com) \n\nALLENTOWN, Pa., Nov. 17, 2023 /PRNewswire/ --\xa0PPL Corporation declared a quarterly common stock dividend on Friday, November 17, of $0.24 per share, payable January 2, 2024, to shareowners of record as of December 8, 2023.\n\nPPL Corporat…   \n\nARTICLE1   ARTICLE SOURCE: Marketscreener.com   ARTICLE TITLE: PPL Corporation reports third-quarter 2023 earnings   ARTICLE DESCRIPTION: (marketscreener.com) net\n16\n10\n51\n36\nInterest Expense\n165\n136\n494\n361\nIncome Before Income Taxes\n288\n215\n797\n713\nIncome Taxes\n58\n41\n170\n147\nNet Income\n$\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 230\n$\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0...https://www.marketscreener.com/quote/stock/PPL-CORPORATION-14091/new…   \n\nARTICLE2   ARTICLE SOURCE: Marketscreener.com   ARTICLE TITLE: PPL to attend 58th EEI Financial Conference   ARTICLE DESCRIPTION: (marketscreener.com) \n\nALLENTOWN, Pa., Nov. 10, 2023 /PRNewswire/ -- PPL Corporation senior leadership will attend the 58th Edison Electric Institute Financial Conference this Sunday, Nov. 12, to Tuesday, Nov. 14, in Phoenix.\n\nDuring the conference, company l…   \n\nARTICLE3   ARTICLE SOURCE: Marketscreener.com   ARTICLE TITLE: PPL\'s Kentucky subsidiaries receive constructive regulatory order approving substantial portion of generation investment plan   ARTICLE DESCRIPTION: (marketscreener.com) \n\nApprovals include retirement of 600 MW of aging coal generation and additions of one approximately 640-MW combined cycle natural gas plant and more than 1,000 MW of solar and energy storage by 2027.PPL reaffirms capital outlook; continu…   \n\nARTICLE4   ARTICLE SOURCE: InvestorsObserver   ARTICLE TITLE: Pembina Pipeline Corporation Announces Conversion Results for Series 1 Preferred Shares   ARTICLE DESCRIPTION: Pembina Pipeline Corporation ("Pembina") (TSX: PPL; NYSE: PBA) announced today that none of Pembina\'s Cumulative Redeemable Rate Reset Class A Preferred Shares, Series 1 ("Series 1 Shares") (TSX: PPL.PR.A) will be converted into Cumulative Redeemable F...   \n\nARTICLE5   ARTICLE SOURCE: ETF Daily News   ARTICLE TITLE: PPL (NYSE:PPL) Issues FY23 Earnings Guidance   ARTICLE DESCRIPTION: PPL (NYSE:PPL – Get Free Report) updated its FY23 earnings guidance on Thursday. The company provided EPS guidance of $1.55-1.60 for the period, compared to the consensus EPS estimate of $1.58. Analyst Ratings Changes PPL has been the subject of a number of r…   \n\nARTICLE6   ARTICLE SOURCE: ETF Daily News   ARTICLE TITLE: PPL Co. (NYSE:PPL) Receives Consensus Rating of “Hold” from Brokerages   ARTICLE DESCRIPTION: Shares of PPL Co. (NYSE:PPL – Get Free Report) have earned a consensus recommendation of “Hold” from the six research firms that are currently covering the firm, MarketBeat reports. Four investment analysts have rated the stock with a hold rating and two have…   \n\nARTICLE7   ARTICLE SOURCE: ETF Daily News   ARTICLE TITLE: Terna (OTCMKTS:TERRF) vs. PPL (NYSE:PPL) Head to Head Analysis   ARTICLE DESCRIPTION: Terna (OTCMKTS:TERRF – Get Free Report) and PPL (NYSE:PPL – Get Free Report) are both utilities companies, but which is the superior investment? We will contrast the two businesses based on the strength of their institutional ownership, dividends, analyst rec…   \n\nARTICLE8   ARTICLE SOURCE: ETF Daily News   ARTICLE TITLE: PPL (NYSE:PPL) Price Target Increased to $30.00 by Analysts at Morgan Stanley   ARTICLE DESCRIPTION: PPL (NYSE:PPL – Get Free Report) had its price target boosted by analysts at Morgan Stanley from $28.00 to $30.00 in a note issued to investors on Tuesday, Benzinga reports. The brokerage currently has an “overweight” rating on the utilities provider’s stock.…   \n\nARTICLE9   ARTICLE SOURCE: ETF Daily News   ARTICLE TITLE: Hotchkis & Wiley Capital Management LLC ...

# %%
def split_into_chunks(text, chunk_size=4000):
    return [text[i:i+chunk_size] for i in range(0, len(text), chunk_size)]

def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.encoding_for_model(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

def ppl_news_entities_extractor(self):
    response_schemas = [
        ResponseSchema(name="Positive News", description="List of Positive News Articles about **PPL Corporation**, if any else return no news"),
        ResponseSchema(name="Positive Aspect", description="List of Topics discussed by the Positive News Articles about **PPL Corporation**, if any else return no news"),
        ResponseSchema(name="Negative News", description="List of Negative News Articles about **PPL Corporation**, if any else return no news"),
        ResponseSchema(name="Negative Aspect", description="List of Topics discussed by the Negative News Articles about **PPL Corporation**, if any else return no news"),
        ResponseSchema(name="Neutral News", description="List of Neutral News Articles about **PPL Corporation**, if any else return no news"),
        ResponseSchema(name="Neutral Aspect", description="List of Topics discussed by the Neutral News Articles about **PPL Corporation**, if any else return no news"),
        ResponseSchema(name="Publish Date", description="List of dates the articles was published, if any else return no news"),
    ]
    output_parser = StructuredOutputParser.from_response_schemas(response_schemas)
    format_instructions = output_parser.get_format_instructions()

    chat_model = ChatOpenAI(model_name="gpt-3.5-turbo-16k", temperature=0.5, openai_api_key = "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")

    prompt = ChatPromptTemplate(
        messages=[
            HumanMessagePromptTemplate.from_template("""
            You are a helpful assistant who evaluates news articles for the day split by "\n\n", identifies positive and negative news about **PPL Corporation** and summarizes it in a concise format.
            {format_instructions}
            News Articles: {question}""")
        ],
        input_variables=["question"],
        partial_variables={"format_instructions": format_instructions}
    )

    topic_dict = {}
    token_check = 0
    clean_transcript = input_to_llm_two[:16000]
    transcription_token_length = num_tokens_from_string(clean_transcript, "gpt-3.5-turbo-16k")
    if transcription_token_length<16000:
      _input = prompt.format_prompt(question=clean_transcript)
      output = chat_model(_input.to_messages())
      return(output_parser.parse(output.content))
    else:
      print("Token Limit Exceeded. Summarizing and evaluating")
      complete_content_chunks = split_into_chunks(clean_transcript,16000)
      summarized_transcription = []
      for chunk in complete_content_chunks:
        doc =  Document(page_content=chunk, metadata={"source": "transcription"})
        summ_chain = load_summarize_chain(chat_model, chain_type="stuff")
        transcription = summ_chain.run([doc])
        summarized_transcription.append(transcription)
      summarized_transcription = ' '.join(summarized_transcription)
      summ_chain = load_summarize_chain(chat_model, chain_type="stuff")
      doc_summarized =  Document(page_content=summarized_transcription, metadata={"source": "summarized_transcription"})
      summarized_transcription_updated = summ_chain.run([doc_summarized])
      _input = prompt.format_prompt(question=summarized_transcription_updated+'\nURL: '+str(list(self.transcriptions.keys())[0]))
      output = chat_model(_input.to_messages())
      topic_dict[output_parser.parse(output.content)['URL']] = output_parser.parse(output.content)
      return(output_parser.parse(output.content))

# %%
response = ppl_news_entities_extractor(input_to_llm_two)
output_df = pd.DataFrame(columns=['Positive News','Positive Aspect','Negative News','Negative Aspect','Neutral News','Neutral Aspect','Publish Date'])
output_df = output_df.append({'Positive News':response['Positive News'],'Positive Aspect':response['Positive Aspect'],'Negative News':response['Negative News'], 'Negative Aspect':response['Negative Aspect'],'Neutral News':response['Neutral News'], 'Neutral Aspect':response['Neutral Aspect'], 'Publish Date':response['Publish Date']}, ignore_index=True)
output_df
# Out:
# WARNING:py.warnings:<ipython-input-188-eda6e6528edb>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output_df = output_df.append({'Positive News':response['Positive News'],'Positive Aspect':response['Positive Aspect'],'Negative News':response['Negative News'], 'Negative Aspect':response['Negative Aspect'],'Neutral News':response['Neutral News'], 'Neutral Aspect':response['Neutral Aspect'], 'Publish Date':response['Publish Date']}, ignore_index=True)
#                                        Positive News  \
# 0  PPL to Pay Quarterly Stock Dividend January 2,...
#
#                    Positive Aspect Negative News Negative Aspect  \
# 0  Quarterly common stock dividend          None            None
#
#                                         Neutral News  \
# 0  PPL Corporation reports third-quarter 2023 ear...
#
#                                       Neutral Aspect       Publish Date
# 0  Third-quarter earnings, attendance at financia...  November 17, 2023

# %%
output_df['Positive News'].iloc[0]
# Out:
# 'PPL to Pay Quarterly Stock Dividend January 2, 2024'

# %%
output_df['Neutral News'].iloc[0].split(',')
# Out:
# ['PPL Corporation reports third-quarter 2023 earnings',
#  ' PPL to attend 58th EEI Financial Conference',
#  " PPL's Kentucky subsidiaries receive constructive regulatory order approving substantial portion of generation investment plan"]

# %%
output_df['Negative News'].iloc[0]
# Out:
# 'None'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

review_df = pd.DataFrame(columns=['Review'])

# Loop through all pages
for i in range(10):
  # Send GET request and retrieve HTML content
  response = requests.get('https://www.yelp.com/biz/ppl-electric-utilities-allentown?start=10')
  soup = BeautifulSoup(response.content, 'html.parser')
  comment_sections = soup.find_all('div', {'class': 'css-9ul5p9'})
  # List to hold reviews
  reviews = []

  # Loop through all divs and extract the text
  for div in comment_sections:
      review_p = div.find("p", class_="comment__09f24__D0cxf")
      if review_p:
          review_text = review_p.get_text(strip=True)
          reviews.append(review_text)

  # Convert list to DataFrame
  df_reviews = pd.DataFrame(reviews, columns=['Review'])
  review_df = pd.concat([review_df,df_reviews])

review_df
# Out:
#                                                Review
# 0   Rude and obnoxious Tried to charge my card wit...
# 1   I would give them no stars if available!   Lat...
# 2   Worse company ever.  They seems incompetent of...
# 3   I sent in ID to start service via email. Don't...
# 4   The person in charge of customer service shoul...
# ..                                                ...
# 5   Following a move to Pennsylvania (Poconos), I ...
# 6   Reading the prior reviews of this organization...
# 7   Service reps suck it's all Bout Ppl taking eve...
# 8   my  name is natasha edwards i worked here for ...
# 9   Allows their staff to call customers calling t...
#
# [100 rows x 1 columns]

# %%
review_df.reset_index(drop=True, inplace=True)

# %%
input_to_llm_three = ""

for index in review_df.index:
  input_to_llm_three+="Review"+str(index)+": "
  input_to_llm_three+="Review: "+review_df.at[index,'Review']
  input_to_llm_three+="\n\n"

input_to_llm_three
# Out:
# "Review0: Review: Rude and obnoxious Tried to charge my card without my permission after I had already paid my bill mind you. Now due to their own error I have to send it Western Union. They refuse to have a discussion about it. No wonder everyone complains about them.\n\nReview1: Review: I would give them no stars if available!   Lately we are getting 2 or more bills a month from them.   I called and of course, did not get an English speaking person.   They stated that they are getting caught up on the wrong billing issues they were having previously.   Not happy at all with PPL any longer.   They used to be the best, now they are the worst!!!!!!!!!!!   Do NOT recommend them at all.\n\nReview2: Review: Worse company ever.  They seems incompetent of fixing customer's problems and concerns. I haven't gotten a bill since January but yet still money are still being charged with no end cycle. Been trying to contact them but no one seems to can tell you something logical\n\nReview3: Review: I sent in ID to start service via email. Don't ever send an email because it is not maintained or checked (a customer service representative advised)!!!! Our service was shut off so I called and it went to a call center in India. The rep said our documents were received and our electric would be turned back on shortly. Never turned on. Called the next day and the rep said the ID cannot be emailed it must be faxed or mailed. JOIN THE 21st CENTURY PPL!!! She then indicated it would only be 2 hours until it would be turned back on. Called back and spoke with a different person and they said that timeframe is wrong. After I faxed the document , I called back in an hour and they still had not confirmed they received anything !!  Are they working with dot matrix printers as well?!? WORST SERVICE EVER!!!!\n\nReview4: Review: The person in charge of customer service should be immediately terminated.  PP&L provides the absolute worst customer service of any company that I have dealt with in 50 years.  Ordered service on January 31, was turned on and two days later turned off.  Called again, waited 84 minutes for an agent, was told it was turned on immediately, it was not, called again, waited 91 minutes for an agent, was told it will be turned on, that day, it was not.  Called again, waited 72 minutes for an agent, was told it will be turned on tomorrow.  Now 6 days later still no service\n\nReview5: Review: Following a move to Pennsylvania (Poconos), I opened an account with PPL. Since I was a new customer I was told I would have to pay a security deposit of $444, but after one year of paying bills on time that money would be used toward future bills. Well it has been 14 months, with an excellent payment record and I keep getting billed. I've tried calling three times to remedy this and each time I have waited over 30 minutes on hold with no one answering. One other time a rep picked up in record time, but transferred me to Billing, where again I waited 30 minutes with no one answering.The only way to contact this company is by phone (really - 30 minutes waiting and no one picking up), or by letter. In this day and age no contact via email. Probably because there would be a record of how many people tried to reach them and how many times each person tried.I can't believe a public utility can be so inattentive and indifferent. My next move will be lodging a complaint with the BBB and the governor's office.\n\nReview6: Review: Reading the prior reviews of this organization is mind-numbing, because they're not only just awful and likely shared by most of PPL's customers, but also because they clearly haven't cleaned up their act despite the rancor from their customers. This is the last place I should be reviewing a power service, but the utilities sector has completely hijacked the pandemic and has decided that its vulnerable customers, many who have been to struggle financially due to lockdowns, should take it up the keister.I've been a customer for over  ...

# %%
def split_into_chunks(text, chunk_size=4000):
    return [text[i:i+chunk_size] for i in range(0, len(text), chunk_size)]

def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.encoding_for_model(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

def ppl_comments_entities_extractor(self):
    response_schemas = [
        ResponseSchema(name="Positive Comments", description="List of Positive Comments about **PPL Corporation**, if any else return no news"),
        ResponseSchema(name="Positive Aspect", description="List of Topics discussed by the Positive Comments about **PPL Corporation**, if any else return no news"),
        ResponseSchema(name="Negative Comments", description="List of Negative Comments about **PPL Corporation**, if any else return no news"),
        ResponseSchema(name="Negative Aspect", description="List of Topics discussed by the Negative Comments about **PPL Corporation**, if any else return no news"),
        ResponseSchema(name="Neutral Comments", description="List of Neutral Comments about **PPL Corporation**, if any else return no news"),
        ResponseSchema(name="Neutral Aspect", description="List of Topics discussed by the Neutral Comments about **PPL Corporation**, if any else return no news")
    ]
    output_parser = StructuredOutputParser.from_response_schemas(response_schemas)
    format_instructions = output_parser.get_format_instructions()

    chat_model = ChatOpenAI(model_name="gpt-3.5-turbo-16k", temperature=0.5, openai_api_key = "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")

    prompt = ChatPromptTemplate(
        messages=[
            HumanMessagePromptTemplate.from_template("""
            You are a helpful assistant who evaluates reviews about PPL Corporation over a period of time split by "\n\n", identifies positive, negative and neutral comments about **PPL Corporation** and summarizes it in a concise format.
            {format_instructions}
            Comments: {question}""")
        ],
        input_variables=["question"],
        partial_variables={"format_instructions": format_instructions}
    )

    topic_dict = {}
    token_check = 0
    clean_transcript = input_to_llm_three[:16000]
    transcription_token_length = num_tokens_from_string(clean_transcript, "gpt-3.5-turbo-16k")
    if transcription_token_length<16000:
      _input = prompt.format_prompt(question=clean_transcript)
      output = chat_model(_input.to_messages())
      return(output_parser.parse(output.content))
    else:
      print("Token Limit Exceeded. Summarizing and evaluating")
      complete_content_chunks = split_into_chunks(clean_transcript,16000)
      summarized_transcription = []
      for chunk in complete_content_chunks:
        doc =  Document(page_content=chunk, metadata={"source": "transcription"})
        summ_chain = load_summarize_chain(chat_model, chain_type="stuff")
        transcription = summ_chain.run([doc])
        summarized_transcription.append(transcription)
      summarized_transcription = ' '.join(summarized_transcription)
      summ_chain = load_summarize_chain(chat_model, chain_type="stuff")
      doc_summarized =  Document(page_content=summarized_transcription, metadata={"source": "summarized_transcription"})
      summarized_transcription_updated = summ_chain.run([doc_summarized])
      _input = prompt.format_prompt(question=summarized_transcription_updated+'\nURL: '+str(list(self.transcriptions.keys())[0]))
      output = chat_model(_input.to_messages())
      topic_dict[output_parser.parse(output.content)['URL']] = output_parser.parse(output.content)
      return(output_parser.parse(output.content))

# %%
ppl_comments_entities_extractor(input_to_llm_three)
# Out:
# {'Positive Comments': 'No news',
#  'Positive Aspect': 'No news',
#  'Negative News': "Review: Rude and obnoxious Tried to charge my card without my permission after I had already paid my bill mind you. Now due to their own error I have to send it Western Union. They refuse to have a discussion about it. No wonder everyone complains about them.\nReview: I would give them no stars if available!   Lately we are getting 2 or more bills a month from them.   I called and of course, did not get an English speaking person.   They stated that they are getting caught up on the wrong billing issues they were having previously.   Not happy at all with PPL any longer.   They used to be the best, now they are the worst!!!!!!!!!!!   Do NOT recommend them at all.\nReview: Worse company ever.  They seems incompetent of fixing customer's problems and concerns. I haven't gotten a bill since January but yet still money are still being charged with no end cycle. Been trying to contact them but no one seems to can tell you something logical\nReview: I sent in ID to start service via email. Don't ever send an email because it is not maintained or checked (a customer service representative advised)!!!! Our service was shut off so I called and it went to a call center in India. The rep said our documents were received and our electric would be turned back on shortly. Never turned on. Called the next day and the rep said the ID cannot be emailed it must be faxed or mailed. JOIN THE 21st CENTURY PPL!!! She then indicated it would only be 2 hours until it would be turned back on. Called back and spoke with a different person and they said that timeframe is wrong. After I faxed the document , I called back in an hour and they still
ened an account with PPL. Since I was a new customer I was told I would have to pay a security deposit of $444, but after one year of paying bills on time that money would be used toward future bills. Well it has been 14 months, with an excellent payment record and I keep getting billed. I've tried calling three times to remedy this and each time I have waited over 30 minutes on hold with no one answering. One other time a rep picked up in record time, but transferred me to Billing, where again I waited 30 minutes with no one answering.The only way to contact this company is by phone (really - 30 minutes waiting and no one picking up), or by letter. In this day and age no contact via email. Probably because there would be a record of how many people tried to reach them and how many times each person tried.I can't believe a public utility can be so inattentive and indifferent. My next move will be lodging a complaint with the BBB and the governor's office.\nReview: Reading the prior reviews of this organization is mind-numbing, because they're not only just awful and likely shared by most of PPL's customers, but also because they clearly haven't cleaned up their act despite the rancor from their customers. This is the last place I should be reviewing a power service, but the utilities sector has completely hijacked the pandemic and has decided that its vulnerable customers, many who have been to struggle financially due to lockdowns, should take it up the keister.I've been a customer for over 15 years, and these previous review ...
#  'Neutral Aspect': 'Customer service, billing issues, service shutdowns, communication, waiting time on hold'}

# %%
response = ppl_comments_entities_extractor(input_to_llm_three)
output_df_two = pd.DataFrame(columns=['Positive Comments','Positive Aspect','Negative Comments','Negative Aspect','Neutral Comments','Neutral Aspect','Publish Date'])
output_df_two = output_df_two.append({'Positive Comments':response['Positive Comments'],'Positive Aspect':response['Positive Aspect'],'Negative Comments':response['Negative Comments'], 'Negative Aspect':response['Negative Aspect'],'Neutral Comments':response['Neutral Comments'], 'Neutral Aspect':response['Neutral Aspect']}, ignore_index=True)
output_df_two
# Out:
# WARNING:py.warnings:<ipython-input-233-8759273388ed>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output_df_two = output_df_two.append({'Positive Comments':response['Positive Comments'],'Positive Aspect':response['Positive Aspect'],'Negative Comments':response['Negative Comments'], 'Negative Aspect':response['Negative Aspect'],'Neutral Comments':response['Neutral Comments'], 'Neutral Aspect':response['Neutral Aspect']}, ignore_index=True)
#   Positive Comments Positive Aspect  \
# 0           No news         No news
#
#                                    Negative Comments  \
# 0  Rude and obnoxious Tried to charge my card wit...
#
#                                      Negative Aspect Neutral Comments  \
# 0  Customer service, Billing issues, Service disc...          No news
#
#   Neutral Aspect Publish Date
# 0        No news          NaN

# %%
output_df.to_csv(r'/content/news_info.csv')

# %%
output_df_two.to_csv(r'/content/comments_info.csv')

# %%
#review_df = pd.DataFrame(columns=['Review'])

# Loop through all pages
#for i in range(10):
# Send GET request and retrieve HTML content

response = requests.get('https://www.papowerswitch.com/shop-for-electricity/shop-for-your-home/')
soup = BeautifulSoup(response.content, 'html.parser')
comment_sections = soup.find_all('div', {'class': 'distributor-estimated-rated'})
comment_sections
# Out:
# [<div class="distributor-estimated-rated">
#  <span data-intro="Get an estimate based on monthly usage (entered above)." data-position="right" data-step="6" id="calculated">$0.00</span>
#  <span id="future-calculated" style="display: none;">$51.87</span>
#  <span class="info term-help" title="Estimate based on monthly usage (entered above), the supplier's price per kWh hour and monthly fees listed under this offer. %distributor% last updated this rate on %lastupdated%.">
#                                                  Estimated per Month <img alt="" src="/Assets/images/icon_help.png"/>
#  </span>
#  </div>]
